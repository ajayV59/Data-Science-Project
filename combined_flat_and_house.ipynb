# %%
import pandas as pd
import numpy as np

# %%
# Mounting google drive account in colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
pd.reset_option('display.max_rows')

# %%
flats = pd.read_csv('/content/drive/MyDrive/Capstone_Project_REAL_ESTATE/flats_data_cleaned_ver1.csv')
houses = pd.read_csv('/content/drive/MyDrive/Capstone_Project_REAL_ESTATE/independent_house_data_cleaned_ver1.csv')

# %%
df = pd.concat([flats, houses],ignore_index=True) #combine data

# %%
df.shape
# Out:
# (3941, 20)

# %%
df = df.sample(df.shape[0],ignore_index=True) #shuffling data

# %%
df.head(20)
# Out:
#                                      property_name property_type  \
# 0                  3 BHK Flat in Sector 90 Gurgaon          flat
# 1                  4 BHK Flat in Sector 69 Gurgaon          flat
# 2                 4 BHK Flat in Sector 108 Gurgaon          flat
# 3                  2 BHK Flat in Sector 92 Gurgaon          flat
# 4                 4 BHK Flat in Sector 111 Gurgaon          flat
# 5    6 Bedroom House for sale in Sector 17 Gurgaon         house
# 6                  3 BHK Flat in Sector 61 Gurgaon          flat
# 7                 3 BHK Flat in Sector 111 Gurgaon          flat
# 8          4 Bedroom House for sale in DLF Phase 3         house
# 9                             3 BHK Flat in Kanahi          flat
# 10  4 Bedroom House for sale in Sector 70A Gurgaon         house
# 11                 4 BHK Flat in Sector 71 Gurgaon          flat
# 12   6 Bedroom House for sale in Sector 48 Gurgaon         house
# ...

# %%
from pathlib import Path

# %%
filepath = Path('/content/drive/MyDrive/Capstone_Project_REAL_ESTATE/gurgaon_real_estate.csv')

# %%
df.to_csv(filepath,index=False)
