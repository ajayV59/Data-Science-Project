# %%
import numpy as np
import pandas as pd

# %%
# Mounting google drive account in colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
pd.reset_option('display.max_rows')

# %%
df = pd.read_csv('/content/drive/MyDrive/Capstone_Project_REAL_ESTATE/flats.csv')

# %%
df.head(2)
# Out:
#                   property_name  \
# 0  2 BHK Flat in Krishna Colony
# 1     2 BHK Flat in Ashok Vihar
#
#                                                 link                 society  \
# 0  https://www.99acres.com/2-bhk-bedroom-apartmen...  maa bhagwati residency
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...            Apna Enclave
#
#     price            area                    areaWithType     bedRoom  \
# 0  45 Lac  ₹ 5,000/sq.ft.  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1  50 Lac  ₹ 7,692/sq.ft.  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
#
#       bathroom    balcony additionalRoom                             address  \
# 0  2 Bathrooms  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  2 Bathrooms  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
# ...

# %%
df.shape #before cleaning
# Out:
# (3028, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3028 non-null   object
#  1   link             3028 non-null   object
#  2   society          3027 non-null   object
#  3   price            3008 non-null   object
#  4   area             3015 non-null   object
#  5   areaWithType     3009 non-null   object
#  6   bedRoom          3009 non-null   object
#  7   bathroom         3009 non-null   object
#  8   balcony          3009 non-null   object
#  9   additionalRoom   1695 non-null   object
#  10  address          3003 non-null   object
#  11  floorNum         3007 non-null   object
#  12  facing           2128 non-null   object
#  13  agePossession    3008 non-null   object
#  14  nearbyLocations  2914 non-null   object
#  15  description      3009 non-null   object
# ...

# %%
df.isnull().sum() #checking # of missing values
# Out:
# property_name         0
# link                  0
# society               1
# price                20
# area                 13
# areaWithType         19
# bedRoom              19
# bathroom             19
# balcony              19
# additionalRoom     1333
# address              25
# floorNum             21
# facing              900
# agePossession        20
# nearbyLocations     114
# description          19
# furnishDetails      824
# features            433
# rating              351
# property_id          19
# dtype: int64

# %%
df.duplicated().sum() #checking duplicates
# Out:
# 0

# %%
df.nunique()
# Out:
# property_name       405
# link               2881
# society             639
# price               440
# area               2131
# areaWithType       1933
# bedRoom               7
# bathroom              8
# balcony               6
# additionalRoom       50
# address            1288
# floorNum            551
# facing                9
# agePossession        49
# nearbyLocations     600
# description        2788
# furnishDetails     1368
# features           1439
# rating              342
# property_id        2875
# dtype: int64

# %%
# dropping unnecessary columns

df.drop(columns=['link','property_id'],inplace=True)

# %%
df.head(2)
# Out:
#                   property_name                 society   price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency  45 Lac
# 1     2 BHK Flat in Ashok Vihar            Apna Enclave  50 Lac
#
#              area                    areaWithType     bedRoom     bathroom  \
# 0  ₹ 5,000/sq.ft.  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1  ₹ 7,692/sq.ft.  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
df['society'].value_counts()
# Out:
# society
# SS The Leaf3.8 ★                             73
# Tulip Violet4.3 ★                            40
# Shapoorji Pallonji Joyville Gurugram4.0 ★    39
# Signature Global Park4.0 ★                   36
# Shree Vardhman Victoria3.8 ★                 35
#                                              ..
# shree kirpalu gi sector 52                    1
# Meditech Apartment                            1
# Mariners Home                                 1
# IMT View Society                              1
# Spire Woods Now Ananda by Alpha corp          1
# Name: count, Length: 639, dtype: int64

# %%
df['society'].value_counts().shape #before
# Out:
# (639,)

# %%
import re

df['society'][7]
# Out:
# 'ATS Triumph3.9 ★'

# %%
re.sub(r'(\d+)?(\.\d+)?\s?\★','',df['society'][7])   #example code to remove rating
# Out:
# 'ATS Triumph'

# %%
# applying regex to remove rating in the text

df['society'] = df['society'].apply(lambda x: re.sub(r'(\d+)?(\.\d+)?\s?\★','',str(x)).strip()).str.lower()

# %%
df['society'].value_counts().shape  #after (605,0)
# Out:
# (605,)

# %%
# rename columns

df.rename(columns={'area':'price_per_sqft'},inplace=True)

# %%
df.head(2)
# Out:
#                   property_name                 society   price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency  45 Lac
# 1     2 BHK Flat in Ashok Vihar            apna enclave  50 Lac
#
#    price_per_sqft                    areaWithType     bedRoom     bathroom  \
# 0  ₹ 5,000/sq.ft.  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1  ₹ 7,692/sq.ft.  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
df[df['price'] == 'Price on Request'].shape
# Out:
# (11, 18)

# %%
df = df[df['price'] != 'Price on Request'] #removing data which has 'price on request' value

# %%
df.shape
# Out:
# (2996, 18)

# %%
# converting price column to float as 'crore'value

def price_convert_numeric(x):
        numeric_part1 = x.replace('Lac', '').strip()
        numeric_part2 = x.replace('Crore', '').strip()
        if 'Lac' in x:
            return round(float(numeric_part1)/100,2)
        else:
            return round(float(numeric_part2),2)

# %%
df.drop([286],inplace=True) # dropping row with 'dataset column headings' as values

# %%
x = df[pd.isna(df['price'])].index

# %%
x
# Out:
# Index([], dtype='int64')

# %%
df.isnull().sum()
# Out:
# property_name         0
# society               0
# price                 0
# price_per_sqft        0
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom     1304
# address               6
# floorNum              2
# facing              874
# agePossession         1
# nearbyLocations      91
# description           0
# furnishDetails      796
# features            407
# rating              328
# dtype: int64

# %%
df.drop(x,inplace=True) # dropping missing values from 'price' column

# %%
df['price'] = df['price'].apply(price_convert_numeric)

# %%
df.head(5)
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
with np.printoptions(threshold=np.inf): #temporarily shows entire numpy array instead of truncated data
    print(df['price_per_sqft'].unique())
# Out:
# ['₹ 5,000/sq.ft.' '₹ 7,692/sq.ft.' '₹ 6,722/sq.ft.' '₹ 12,250/sq.ft.'
#  '₹ 5,204/sq.ft.' '₹ 6,269/sq.ft.' '₹ 13,333/sq.ft.' '₹ 7,860/sq.ft.'
#  '₹ 8,148/sq.ft.' '₹ 16,885/sq.ft.' '₹ 9,767/sq.ft.' '₹ 5,587/sq.ft.'
#  '₹ 6,940/sq.ft.' '₹ 6,859/sq.ft.' '₹ 5,384/sq.ft.' '₹ 16,859/sq.ft.'
#  '₹ 14,084/sq.ft.' '₹ 11,475/sq.ft.' '₹ 10,476/sq.ft.' '₹ 9,156/sq.ft.'
#  '₹ 8,604/sq.ft.' '₹ 7,796/sq.ft.' '₹ 9,135/sq.ft.' '₹ 12,855/sq.ft.'
#  '₹ 7,910/sq.ft.' '₹ 18,331/sq.ft.' '₹ 24,300/sq.ft.' '₹ 5,600/sq.ft.'
#  '₹ 12,784/sq.ft.' '₹ 26,936/sq.ft.' '₹ 10,156/sq.ft.' '₹ 7,194/sq.ft.'
#  '₹ 6,538/sq.ft.' '₹ 5,769/sq.ft.' '₹ 6,950/sq.ft.' '₹ 8,866/sq.ft.'
#  '₹ 5,403/sq.ft.' '₹ 5,714/sq.ft.' '₹ 15,151/sq.ft.' '₹ 6,200/sq.ft.'
#  '₹ 16,000/sq.ft.' '₹ 6,378/sq.ft.' '₹ 3,571/sq.ft.' '₹ 7,846/sq.ft.'
#  '₹ 7,297/sq.ft.' '₹ 7,581/sq.ft.' '₹ 10,005/sq.ft.' '₹ 10,714/sq.ft.'
#  '₹ 16,969/sq.ft.' '₹ 14,545/sq.ft.' '₹ 5,424/sq.ft.' '₹ 7,410/sq.ft.'
# ...

# %%
df['price_per_sqft'].isnull().sum()
# Out:
# 0

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 10,000/sq.ft.    19
# ₹ 8,000/sq.ft.     16
# ₹ 12,500/sq.ft.    16
# ₹ 6,666/sq.ft.     13
# ₹ 5,000/sq.ft.     13
#                    ..
# ₹ 20,602/sq.ft.     1
# ₹ 12,401/sq.ft.     1
# ₹ 6,224/sq.ft.      1
# ₹ 8,179/sq.ft.      1
# ₹ 35,222/sq.ft.     1
# Name: count, Length: 2128, dtype: int64

# %%
# converting to float

df['price_per_sqft'] = df['price_per_sqft'].str.replace('/sq.ft.','').str.replace('₹ ','').str.replace(',','').str.strip().astype('float')

# %%
df.head(2)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
#
#    price_per_sqft                    areaWithType     bedRoom     bathroom  \
# 0          5000.0  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1          7692.0  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
# bedrooms
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 3 Bedrooms    1437
# 2 Bedrooms     943
# 4 Bedrooms     478
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# Name: count, dtype: int64

# %%
df['bedRoom'].isnull().sum()
# Out:
# 0

# %%
# Converting bedroom to numeric

df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head(2)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
#
#    price_per_sqft                    areaWithType  bedRoom     bathroom  \
# 0          5000.0  Carpet area: 900 (83.61 sq.m.)        2  2 Bathrooms
# 1          7692.0  Carpet area: 650 (60.39 sq.m.)        2  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
# bathroom

df['bathroom'].value_counts()
# Out:
# bathroom
# 2 Bathrooms    1043
# 3 Bathrooms     989
# 4 Bathrooms     636
# 5 Bathrooms     169
# 1 Bathroom      112
# 6 Bathrooms      42
# 7 Bathrooms       5
# Name: count, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head(3)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2           2 BHK Flat in Sohna  tulsiani easy in homes   0.40
#
#    price_per_sqft                    areaWithType  bedRoom  bathroom  \
# 0          5000.0  Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0  Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0  Carpet area: 595 (55.28 sq.m.)        2         2
#
#        balcony additionalRoom                             address  \
# 0    1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1    1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
# 2  3 Balconies            NaN             Sohna, Gurgaon, Haryana
#
#               floorNum facing    agePossession  \
# 0    4th   of 4 Floors   West  1 to 5 Year Old
# 1    1st   of 3 Floors   West     10+ Year Old
# ...

# %%
# balcony

df['balcony'].value_counts()
# Out:
# balcony
# 3 Balconies     973
# 3+ Balconies    862
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: count, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df.head(5)
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
# Additional rooms

df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     629
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Study Room,Pooja Room                              8
# Servant Room,Study Room                            8
# ...

# %%
df['additionalRoom'].isnull().sum()
# Out:
# 1304

# %%
df['additionalRoom'].fillna('not available',inplace=True) #replacing null values with not available

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()  #making values lower case

# %%
df.head(5)
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
# floor numbers

df['floorNum'].value_counts()
# Out:
# floorNum
# 2nd   of 4 Floors      74
# 3rd   of 4 Floors      71
# 4th   of 4 Floors      62
# 1st   of 4 Floors      61
# 12nd   of 14 Floors    49
#                        ..
# 4th   of 39 Floors      1
# 24th   of 32 Floors     1
# 8th   of 27 Floors      1
# 28th   of 29 Floors     1
# 23rd   of 36 Floors     1
# Name: count, Length: 550, dtype: int64

# %%
df['floorNum'].isnull().sum()
# Out:
# 2

# %%
df['floorNum'] =  df['floorNum'].str.split(' ').str.get(0).str.replace('Ground','0').str.replace('Lower','0').str.replace('Basement','-1').str.extract(r'(\d+)')

# %%
df.head(4)
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
#
#    price_per_sqft                      areaWithType  bedRoom  bathroom  \
# 0          5000.0    Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0    Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0    Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0  Carpet area: 1200 (111.48 sq.m.)        2         2
#
#   balcony additionalRoom                              address floorNum facing  \
# 0       1  not available     Krishna Colony, Gurgaon, Haryana        4   West
# 1       1  not available   46b, Ashok Vihar, Gurgaon, Haryana        1   West
# ...

# %%
# facing

df['facing'].value_counts()
# Out:
# facing
# North-East    505
# East          489
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# 874

# %%
df[df['facing'].isnull()].head(5)
# Out:
#                              property_name                         society  \
# 2                      2 BHK Flat in Sohna          tulsiani easy in homes
# 3          2 BHK Flat in Sector 61 Gurgaon             smart world orchard
# 4          2 BHK Flat in Sector 92 Gurgaon                parkwood westend
# 5          2 BHK Flat in Sector 36 Gurgaon  signature global infinity mall
# 6  3 BHK Flat in Dwarka Expressway Gurgaon                      the cocoon
#
#    price  price_per_sqft                            areaWithType  bedRoom  \
# 2   0.40          6722.0          Carpet area: 595 (55.28 sq.m.)        2
# 3   1.47         12250.0        Carpet area: 1200 (111.48 sq.m.)        2
# 4   0.70          5204.0  Super Built up area 1345(124.95 sq.m.)        2
# 5   0.41          6269.0        Built Up area: 654 (60.76 sq.m.)        2
# 6   2.00         13333.0  Super Built up area 1500(139.35 sq.m.)        3
#
#    bathroom balcony additionalRoom  \
# ...

# %%
df['facing'].fillna('not available',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# not available    874
# North-East       505
# East             489
# North            301
# South            203
# West             183
# North-West       162
# South-East       144
# South-West       135
# Name: count, dtype: int64

# %%
# inserting additional useful columns

df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.head(3)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2           2 BHK Flat in Sohna  tulsiani easy in homes   0.40
#
#    price_per_sqft   area                    areaWithType  bedRoom  bathroom  \
# 0          5000.0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0  650.0  Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0  595.0  Carpet area: 595 (55.28 sq.m.)        2         2
#
#   balcony additionalRoom                             address floorNum  \
# 0       1  not available    Krishna Colony, Gurgaon, Haryana        4
# 1       1  not available  46b, Ashok Vihar, Gurgaon, Haryana        1
# 2       3  not available             Sohna, Gurgaon, Haryana       12
#
#           facing    agePossession  \
# 0           West  1 to 5 Year Old
# 1           West     10+ Year Old
# ...

# %%
df.insert(loc=1,column='property_type',value='flat')

# %%
df.head(3)
# Out:
#                   property_name property_type                 society  price  \
# 0  2 BHK Flat in Krishna Colony          flat  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar          flat            apna enclave   0.50
# 2           2 BHK Flat in Sohna          flat  tulsiani easy in homes   0.40
#
#    price_per_sqft   area                    areaWithType  bedRoom  bathroom  \
# 0          5000.0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0  650.0  Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0  595.0  Carpet area: 595 (55.28 sq.m.)        2         2
#
#   balcony additionalRoom                             address floorNum  \
# 0       1  not available    Krishna Colony, Gurgaon, Haryana        4
# 1       1  not available  46b, Ashok Vihar, Gurgaon, Haryana        1
# 2       3  not available             Sohna, Gurgaon, Haryana       12
#
#           facing    agePossession  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   property_type    2996 non-null   object
#  2   society          2996 non-null   object
#  3   price            2996 non-null   float64
#  4   price_per_sqft   2996 non-null   float64
#  5   area             2996 non-null   float64
#  6   areaWithType     2996 non-null   object
#  7   bedRoom          2996 non-null   int64
#  8   bathroom         2996 non-null   int64
#  9   balcony          2996 non-null   object
#  10  additionalRoom   2996 non-null   object
#  11  address          2990 non-null   object
#  12  floorNum         2994 non-null   object
#  13  facing           2996 non-null   object
#  14  agePossession    2995 non-null   object
#  15  nearbyLocations  2905 non-null   object
#  16  description      2996 non-null   object
# ...

# %%
df.shape
# Out:
# (2996, 20)

# %%
from pathlib import Path

# %%
filepath = Path('/content/drive/MyDrive/Capstone_Project_REAL_ESTATE/flats_data_cleaned_ver1.csv')

# %%
df.to_csv(filepath,index=False)
